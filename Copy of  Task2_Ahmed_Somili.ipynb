# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %%
df
# Out:
#            City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0      Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1      Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2      Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3      Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4      Abudhabi  2023-07-07 12:01:30                 8         20       62.1
# ...         ...                  ...               ...        ...        ...
# 66634    Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635    Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636    Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637    Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638    Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
# ...

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %%
import pandas as pd

df = pd.read_csv('/content/Dataset_2/Task (2) Dataset.csv')
df.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0         0.7                   13           59.611918       54.803617
# 1         1.7                    8           60.221387       56.118629
# 2         2.8                    6           59.161978       55.518834
# 3         5.5                    6           59.738138       56.413917
# 4         6.5                    5           58.958314       56.059246

# %% [markdown]
# # Tasks

# %%
df.describe()

# %%
unique_values = df['City'].unique()

print(unique_values)
# Out:
# ['Abudhabi' 'Al-ain' 'Cairo' 'Dammam' 'Doha' 'Dubai' 'Jeddah' 'Kuwait'
#  'Mecca' 'Medina' 'Riyadh']

# %%
age_band_description = df['City'].describe()

print("Descriptive statistics for 'Age_band_of_driver':")
print(age_band_description)
# Out:
# Descriptive statistics for 'Age_band_of_driver':
# count     66639
# unique       11
# top        Doha
# freq       8692
# Name: City, dtype: object

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
print(df.shape)
# Out:
# (66639, 9)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   62772 non-null  float64
#  8   TravelTimeLive       62772 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB
# None

# %%
print(df.describe())
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      66639.000000  66639.000000  66639.000000  66639.000000
# mean          14.043113     74.278531    288.353877     49.316135
# std           13.488906    107.452022    470.013224     85.352525
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      9.000000     27.700000      3.000000
# 50%           10.000000     29.000000     95.700000     12.200000
# 75%           21.000000     95.000000    336.600000     53.500000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# count         66639.000000        62772.000000    62772.000000
# mean             13.981737           70.706601       70.048451
# std              13.454922           10.588384       11.966725
# min               0.000000           49.381346       46.723235
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
import matplotlib.pyplot as plt

# Plotting histogram of TrafficIndexWeekAgo
plt.figure(figsize=(10, 6))
plt.hist(df['TrafficIndexWeekAgo'], bins=10, edgecolor='black', alpha=0.7)
plt.xlabel('Traffic Index Week Ago')
plt.ylabel('Frequency')
plt.title('Distribution of Traffic Index Week Ago')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Convert 'Datetime' column to datetime type (if not already done)
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Plotting the distribution of Datetime
plt.figure(figsize=(12, 6))
plt.hist(df['Datetime'], bins=50, edgecolor='black', alpha=0.7)
plt.xlabel('Datetime')
plt.ylabel('Frequency')
plt.title('Distribution of Datetime')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Convert 'Datetime' column to datetime type
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Plotting Traffic Index over time
plt.figure(figsize=(12, 6))
plt.plot(df['Datetime'], df['TrafficIndexLive'], marker='o', linestyle='-', color='b', label='Traffic Index')
plt.xlabel('Datetime')
plt.ylabel('Traffic Index')
plt.title('Traffic Index Variation over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plotting Jams Count and Jams Length over time
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.plot(df['Datetime'], df['JamsCount'], marker='o', linestyle='-', color='g', label='Jams Count')
plt.xlabel('Datetime')
plt.ylabel('Jams Count')
plt.title('Traffic Jams Count over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(df['Datetime'], df['JamsLength'], marker='o', linestyle='-', color='r', label='Jams Length')
plt.xlabel('Datetime')
plt.ylabel('Jams Length (km)')
plt.title('Traffic Jams Length over Time')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming df is already defined as per previous example

# Generate hypothetical weather conditions
np.random.seed(0)
weather_conditions = ['Clear', 'Rainy', 'Cloudy', 'Snowy']
df['WeatherCondition'] = np.random.choice(weather_conditions, size=len(df))

# Explore relationship between TrafficIndexLive and WeatherCondition
plt.figure(figsize=(10, 6))

# Scatter plot with different colors for each weather condition
for weather in weather_conditions:
    subset = df[df['WeatherCondition'] == weather]
    plt.scatter(subset['TrafficIndexLive'], subset.index, label=weather, alpha=0.7)

plt.xlabel('Traffic Index')
plt.ylabel('Index')
plt.title('Traffic Index vs. Weather Condition')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Grouping data by City and calculating mean JamsCount
city_jams_count = df.groupby('City')['JamsCount'].mean().sort_values(ascending=False)

# Plotting bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=city_jams_count.index, y=city_jams_count.values, palette='viridis')
plt.xlabel('City')
plt.ylabel('Mean Jams Count')
plt.title('Mean Jams Count by City')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-17156dd1d4a1>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_jams_count.index, y=city_jams_count.values, palette='viridis')

# %%
# Counting occurrences of each city
city_counts = df['City'].value_counts()

# Plotting pie chart
plt.figure(figsize=(8, 8))
plt.pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Observations by City')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# Violin plot for TrafficIndexWeekAgo by City
plt.figure(figsize=(12, 8))
sns.violinplot(x='City', y='TrafficIndexWeekAgo', data=df, palette='viridis')
plt.xlabel('City')
plt.ylabel('Traffic Index Week Ago')
plt.title('Distribution of Traffic Index Week Ago by City')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-94a5ce99ddc4>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='City', y='TrafficIndexWeekAgo', data=df, palette='viridis')

# %%
# Plotting histograms for TrafficIndexLive and JamsDelay
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(df['TrafficIndexLive'], bins=20, edgecolor='black', alpha=0.7)
plt.xlabel('Traffic Index Live')
plt.ylabel('Frequency')
plt.title('Distribution of Traffic Index Live')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.hist(df['JamsDelay'], bins=20, edgecolor='black', alpha=0.7)
plt.xlabel('Jams Delay')
plt.ylabel('Frequency')
plt.title('Distribution of Jams Delay')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# ### Temporal Coverage and Frequency
# Insight: The histogram illustrates the distribution of datetime values, indicating the temporal coverage and frequency of data points throughout the dataset.
#
#
# ###Temporal Granularity
# Insight: Binning datetime values into 50 bins shows the granularity of temporal data points, highlighting intervals with varying frequencies of observations.

# %% [markdown]
# ### Variation in Jams Count by City
# Analysis: Riyadh shows the highest mean jams count among the cities studied, indicating more frequent and potentially longer traffic delays.
# Implications: This suggests that Riyadh may face greater traffic congestion challenges compared to Abudhabi and other cities in the dataset, necessitating focused traffic management strategies and infrastructure improvements.
#
#
# ### Contrasting Traffic Patterns
# Analysis: Abudhabi exhibits a lower mean jams count compared to Riyadh but higher than other cities in the dataset.
# Implications: The disparities in jams count between Abudhabi and Riyadh highlight differing urban traffic patterns and infrastructure capacities, influencing urban planning decisions and resource allocation for traffic management initiatives.

# %% [markdown]
# ###Traffic Index Live
# Distribution Analysis: The histogram for 'TrafficIndexLive' reveals a skewed right distribution, indicating that most observations have lower traffic indices.
#
#
# Implications: This suggests that traffic conditions are generally moderate, with occasional spikes indicating periods of high congestion.
#
#
# ###Jams Delay
# Distribution Analysis: The histogram for 'JamsDelay' also shows a right-skewed distribution, indicating that most delays are relatively short.
# Implications: Occasional outliers represent longer delays, likely occurring during peak traffic hours or due to specific incidents.

# %% [markdown]
# ###Draw conclusions based on the patterns observed in the data.

# %% [markdown]
# The dataset shows varying traffic conditions across cities, with Riyadh experiencing the highest mean jams count, indicating significant congestion challenges.
#
# Abudhabi, while showing lower jams counts than Riyadh, still exhibits notable traffic issues compared to other cities studied.
#
# Temporal analysis reveals data collected from July to December 2023, with fluctuating data densities over time, crucial for understanding temporal trends.
#
# Traffic indices and delays follow right-skewed distributions, suggesting moderate conditions with occasional peaks, particularly during peak traffic hours or specific incidents.
#
# Addressing these traffic patterns requires targeted infrastructure improvements and responsive traffic management strategies tailored to each city's unique challenges.
#
# Insights from these analyses support informed urban planning decisions aimed at enhancing traffic flow efficiency and overall urban mobility.
