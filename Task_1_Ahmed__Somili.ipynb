# %% [markdown]
# <a href="https://colab.research.google.com/github/7iz7/T5W1/blob/main/Task_1_Ahmed__Somili.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd

df = pd.read_csv('/content/Dataset_1/Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df['Vehicle_driver_relation'].fillna('Non', inplace=True)
df['Driving_experience'].fillna('Non', inplace=True)
df['Type_of_vehicle'].fillna('Non', inplace=True)
df['Owner_of_vehicle'].fillna('Non', inplace=True)
df['Service_year_of_vehicle'].fillna('Non', inplace=True)
df['Defect_of_vehicle'].fillna('Non', inplace=True)
df['Lanes_or_Medians'].fillna('Non', inplace=True)
df['Area_accident_occured'].fillna('Non', inplace=True)
df['Road_allignment'].fillna('Non', inplace=True)
df['Work_of_casuality'].fillna('Non', inplace=True)
df['Road_allignment'].fillna('Non', inplace=True)
df['Types_of_Junction'].fillna('Non', inplace=True)
df['Road_surface_type'].fillna('Non', inplace=True)
df['Fitness_of_casuality'].fillna('Non', inplace=True)
df['Vehicle_movement'].fillna('Non', inplace=True)
df['Type_of_collision'].fillna('Non', inplace=True)

# %%
# Descriptive statistics for 'Age_band_of_driver'
age_band_description = df['Age_band_of_driver'].describe()

print("Descriptive statistics for 'Age_band_of_driver':")
print(age_band_description)
# Out:
# Descriptive statistics for 'Age_band_of_driver':
# count     12316
# unique        5
# top       18-30
# freq       4271
# Name: Age_band_of_driver, dtype: object

# %%
df['Age_band_of_casualty'].describe()
# Out:
# count     12316
# unique        6
# top          na
# freq       4443
# Name: Age_band_of_casualty, dtype: object

# %%
unique_values = df['Age_band_of_casualty'].unique()

print(unique_values)
# Out:
# ['na' '31-50' '18-30' 'Under 18' 'Over 51' '5']

# %%
import pandas as pd

unique_values = df['Age_band_of_casualty'].unique()
print("Unique values in 'Age_band_of_casualty':")
print(unique_values)

value_counts = df['Age_band_of_casualty'].value_counts()
print("\nValue counts for 'Age_band_of_casualty':")
print(value_counts)
# Out:
# Unique values in 'Age_band_of_casualty':
# ['na' '31-50' '18-30' 'Under 18' 'Over 51' '5']
#
# Value counts for 'Age_band_of_casualty':
# Age_band_of_casualty
# na          4443
# 18-30       3145
# 31-50       2455
# Under 18    1035
# Over 51      994
# 5            244
# Name: count, dtype: int64

# %%
df['Educational_level'].fillna('Non', inplace=True)

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
# ????

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
# ????

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
print(df.shape)
# Out:
# (12316, 32)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            12316 non-null  object
#  5   Vehicle_driver_relation      12316 non-null  object
#  6   Driving_experience           12316 non-null  object
#  7   Type_of_vehicle              12316 non-null  object
#  8   Owner_of_vehicle             12316 non-null  object
#  9   Service_year_of_vehicle      12316 non-null  object
#  10  Defect_of_vehicle            12316 non-null  object
#  11  Area_accident_occured        12316 non-null  object
#  12  Lanes_or_Medians             12316 non-null  object
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example data
age_band_data = df['Age_band_of_driver'].value_counts()

# Plotting using Matplotlib
plt.figure(figsize=(8, 6))
age_band_data.plot(kind='bar')
plt.title('Distribution of Age Bands of Drivers')
plt.xlabel('Age Band')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
print(df['Accident_severity'].head(10))
# Out:
# 0     Slight Injury
# 1     Slight Injury
# 2    Serious Injury
# 3     Slight Injury
# 4     Slight Injury
# 5     Slight Injury
# 6     Slight Injury
# 7     Slight Injury
# 8     Slight Injury
# 9    Serious Injury
# Name: Accident_severity, dtype: object

# %%
# plt.figure(figsize=(10, 6))
# sns.countplot(data=df, x='Type_of_vehicle', order=vehicle_type_counts.index)
# plt.title('Distribution of Vehicle Types')
# plt.xlabel('Type of Vehicle')
# plt.ylabel('Count')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group data by Age_band_of_driver and Accident_severity
severity_by_age = df.groupby(['Age_band_of_driver', 'Accident_severity']).size().unstack()

# Plotting using Matplotlib
severity_by_age.plot(kind='bar', figsize=(12, 8))
plt.title('Distribution of Accident Severity by Age Band of Driver')
plt.xlabel('Age Band of Driver')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Accident Severity')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Age_band_of_driver'], bins=5, kde=False, color='skyblue')
plt.title('Histogram of Age Bands of Drivers')
plt.xlabel('Age Band')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colors = sns.color_palette("Set2")



plt.figure(figsize=(8, 8))
severity_counts = df['Accident_severity'].value_counts()
severity_counts.plot.pie(autopct='%1.1f%%', startangle=140, colors=colors)

plt.title('Proportion of Accident Severity')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Day_of_week')
plt.title('Number of Accidents by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Accident_severity', data=df, palette='viridis')
plt.title('Distribution of Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-60-59df067bdf54>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Accident_severity', data=df, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example data
ownership_data = df['Owner_of_vehicle'].value_counts()

# Plotting using Matplotlib
plt.figure(figsize=(8, 6))
ownership_data.plot(kind='bar', color='skyblue')
plt.title('Distribution of Vehicle Ownership')
plt.xlabel('Owner/Non-Owner')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
vehicle_counts = df['Type_of_vehicle'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(vehicle_counts, labels=vehicle_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen'])
plt.title('Distribution of Types of Vehicles')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df['Service_year_of_vehicle'] contains the data you want to plot

plt.figure(figsize=(10, 6))
sns.histplot(df['Service_year_of_vehicle'], bins=20, kde=True)
plt.title('Distribution of Service Year of Vehicle')
plt.xlabel('Service Year of Vehicle')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# ```
#
# ```
#
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# 1.  The majority of drivers involved in accidents are in the age group of 18-30 and 31-50 years old.
#
# 2. Male drivers are significantly more involved in accidents compared to female drivers.
#
# 3. On Fridays, traffic accidents are more prevalent.
#
# 4. A significant portion of vehicles involved are owned by their drivers.

# %% [markdown]
# Based on these patterns, it appears that there are clear demographic and behavioral trends contributing to road incidents. Strategies to reduce incidents could focus on targeted education and awareness campaigns for male drivers in the identified age groups, promoting safer driving practices such as maintaining safe distances and adhering to traffic rules during peak hours. Additionally, enhancing enforcement measures during critical times could mitigate risks associated with high-frequency activities like lane changes and overtaking maneuvers. Further analysis could explore correlations between specific behaviors and injury severity to refine interventions aimed at reducing road incidents and improving overall road safety.
